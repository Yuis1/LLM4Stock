# %% [markdown]
# ## 目标
# 使用预训练的大语言模型（LLM），通过Prompt方式，对输入的新闻资讯进行解读，评估并返回利好程度。
# 可选的LLM包括：
# · GPT4
# · LLama
#
#
# ## 方案
# 1. ChatGPT API默认不记住上下文，每轮对话都需要重新发送设定信息。不支持指定conversation_id来实现多轮对话连贯性。
# 2. 即使一次对话中给了多条user身份的content，ChatGPT API也仅对第一条返回response。
# 3. 如果将多条问题通过json格式一次性塞进单条content中，并要求同样在返回的单条response中用json包括多条回答，也可以做到，但是解析起来比较麻烦，节约不了太多Token。
# 4. 最终设计方案：逐条新闻解读，每轮对话用system身份设定背景条件，单条新闻附加到user身份的content。

# %%
import openai
import pandas as pd
import json
import requests
import re

from dotenv import dotenv_values, load_dotenv
load_dotenv('.env') # 从配置文件中读取密钥，实现配置和代码分离。参考： https://juejin.cn/post/7099283807953977358
env_vars = dotenv_values()

# %%
# 读取财联社-电报
stock_cls_telegram_df = pd.read_csv('data/stock_cls_telegram.csv')
# 数据清洗：去除NaN值，填充为空字符串
stock_cls_telegram_df = stock_cls_telegram_df.fillna('') 
# '利好评估'列：评估本条新闻对股票的利好程度，单值，从以下选项中选取一个：强烈利好、利好、中性、利空、强烈利空、无法判断
# '新闻解读'列：对本条新闻使用自然语言进行解读，给出思考过程
# '评估状态'列：用于存储评估状态，从以下选项中选取一个：已评估 ，''-未评估，无法评估
# 如果不存在'利好评估'、‘新闻解读’、‘已评估’列，则增加
if '利好评估' not in stock_cls_telegram_df.columns:
    stock_cls_telegram_df['利好评估'] = ''
if '新闻解读' not in stock_cls_telegram_df.columns:
    stock_cls_telegram_df['新闻解读'] = ''
if '评估状态' not in stock_cls_telegram_df.columns:
    stock_cls_telegram_df['评估状态'] = ''

# %%
# 定义一个用户计算token数量的函数，防止超过模型的token数量限制。
# 需要注意的是，此处仅计算输入的Token数量，不包括模型自动生成的Token数量。实际的限制中，还需要加上模型自动生成的Token数量。
import tiktoken
def num_tokens_from_messages(messages, model="gpt-3.5-turbo-0613"):
    """Return the number of tokens used by a list of messages."""
    try:
        encoding = tiktoken.encoding_for_model(model)
    except KeyError:
        print("Warning: model not found. Using cl100k_base encoding.")
        encoding = tiktoken.get_encoding("cl100k_base")
    if model in {
        "gpt-3.5-turbo-0613",
        "gpt-3.5-turbo-16k-0613",
        "gpt-4-0314",
        "gpt-4-32k-0314",
        "gpt-4-0613",
        "gpt-4-32k-0613",
        }:
        tokens_per_message = 3
        tokens_per_name = 1
    elif model == "gpt-3.5-turbo-0301":
        tokens_per_message = 4  # every message follows <|start|>{role/name}\n{content}<|end|>\n
        tokens_per_name = -1  # if there's a name, the role is omitted
    elif "gpt-3.5-turbo" in model:
        print("Warning: gpt-3.5-turbo may update over time. Returning num tokens assuming gpt-3.5-turbo-0613.")
        return num_tokens_from_messages(messages, model="gpt-3.5-turbo-0613")
    elif "gpt-4" in model:
        print("Warning: gpt-4 may update over time. Returning num tokens assuming gpt-4-0613.")
        return num_tokens_from_messages(messages, model="gpt-4-0613")
    else:
        raise NotImplementedError(
            f"""num_tokens_from_messages() is not implemented for model {model}. See https://github.com/openai/openai-python/blob/main/chatml.md for information on how messages are converted to tokens."""
        )
    num_tokens = 0
    for message in messages:
        num_tokens += tokens_per_message
        for key, value in message.items():
            num_tokens += len(encoding.encode(value))
            if key == "name":
                num_tokens += tokens_per_name
    num_tokens += 3  # every reply is primed with <|start|>assistant<|message|>
    return num_tokens

# %%
# 功能：使用OpenAI GPT对新闻进行解读
# 最终对接的是Chat接口 https://platform.openai.com/docs/api-reference/chat，对应API2D接口 https://api2d-doc.apifox.cn/api-84787447
# 各个模型的描述和上下文限制：https://platform.openai.com/docs/models/overview

# OpenAI 在国内无法直接调用，需要使用代理
# openai.api_key = env_vars['openai_key']

# 使用api2d.net代理
import requests
url = "https://openai.api2d.net/v1/chat/completions"

api2d_Authorization = env_vars['api2d_Authorization']
headers = {
  'Content-Type': 'application/json',
  'Authorization': api2d_Authorization
}

# messages：对话列表，包含系统提示和用户输入
messages = []

# system_prompt：比较复杂，从本地文件读取
system_prompt = open('system_prompt.md', 'r').read()
messages = [{"role": "system", "content": system_prompt}]

# 构建token数量限制的字典。tokens限制：https://platform.openai.com/docs/models/gpt-3-5
# token_limit = {"gpt-3.5-turbo": 4096,"gpt-3.5-turbo-0613": 4096,  "gpt-3.5-turbo-16k": 16384,"gpt-3.5-turbo-16k-0613": 16384, "gpt-4": 8192,"gpt-4-0613": 8192, "gpt-4-32k": 32768,  "gpt-4-32k-0613": 32768}

# 定义新闻评估函数，功能包括：计算messages的token数量、根据messages批量生成新闻解读
# 入参包括：模型消息 messages，模型名称 model
def stock_eval(messages, model):
    # # 计算messages的token数量。
    # messages_tokens=num_tokens_from_messages(messages, model)
    # print(f"messages_tokens:{messages_tokens}")

    # 生成一次新闻解读
    # response=openai.ChatCompletion.create(  # OpenAI接口国内连不通
    #     model=model, 
    #     messages=messages,
    #     max_tokens=token_limit[model] - messages_tokens-100, # 此处定义可返回的最大tokens数量。限制条件：messages的tokens + max_tokens返回的最大tokens <= token_limit 总tokens限制。留100个tokens用于宽限。
    #     temperature=0 # between 0 and 2. Lower values like 0.2 will make it more focused and deterministic.
    # )

    # 使用api2d.net代理
    url = "https://oa.api2d.net/v1/chat/completions"
    # messages_tokens=num_tokens_from_messages(messages, model)
    payload = json.dumps({
    "model": model,
    "messages":messages,
    "safe_mode": False,
    # "max_tokens": token_limit[model] - messages_tokens -100, # 此处定义可返回的最大tokens数量。限制条件：messages的tokens + max_tokens返回的最大tokens <= token_limit 总tokens限制。留100个tokens用于宽限。
    "temperature":0 # between 0 and 2. Lower values like 0.2 will make it more focused and deterministic.
    })
    headers = {
    'Authorization': api2d_Authorization,
    'User-Agent': 'Apifox/1.0.0 (https://apifox.com)',
    'Content-Type': 'application/json'
    }
    response = requests.request("POST", url, headers=headers, data=payload)
    print(response.text)
    response_dict = response.json()  # 将响应内容转换为字典

    content=response_dict['choices'][0]['message']['content'] 
    try:
        eval = re.findall(r'eval: (.*)\n', content)[0]  # 解析出利好评估
        cot = re.findall(r'COT: (.*)', content)[0] # 解析出新闻解读
        status = '已评估'
    except:
        eval = ''
        cot = ''
        status = ''
    return {"eval": eval, "cot": cot, "status": status}

# 构建user_prompt。
model="gpt-3.5-turbo" # 调用模型名称
# print(f"system_prompt tokens: {num_tokens_from_messages(messages, model)}")

for index, row in stock_cls_telegram_df.iterrows():
    if row['匹配证券代码'] == '' : # 如果 ‘匹配证券代码’ 为空，则 '评估状态' 列填充为 '无法评估'
        stock_cls_telegram_df.loc[index, '评估状态'] = '无法评估'
        continue # 跳出本次循环，继续下一次循环

    if row['评估状态'] == '' :  # 需要评估的新闻，仅包含 '评估状态'为空 的行
        # 通过本条新闻，构建单条user_prompt
        # user_prompt：读取stock_cls_telegram_eval_df中的'提取证券名称'、‘内容’列，构建user_prompt
        user_prompt = "stock"+row['提取证券名称']+"\n"+"content: "+row['内容']
        print(user_prompt)
        user_prompt = json.dumps(user_prompt,ensure_ascii=False) # 将字典转换为json格式的文本类型，否则会报错。ensure_ascii=False，保证中文不会被转换为ascii码。
        messages.append({"role": "user", "content": user_prompt})
        result = stock_eval(messages, model) # 调用新闻评估函数
        messages = [{"role": "system", "content": system_prompt}] # 清空并重新构建messages
        # 保存结果
        stock_cls_telegram_df.loc[index, '利好评估'] = result["eval"]
        stock_cls_telegram_df.loc[index, '新闻解读'] = result["cot"]
        stock_cls_telegram_df.loc[index, '评估状态'] = result["status"]
        stock_cls_telegram_df.to_csv('data/stock_cls_telegram.csv', index=False, encoding='utf-8-sig')
# Out:
# stock汇川技术
# content: 【汇川技术：SCARA机器人份额在中国市场提升到第二名】财联社9月19日电，汇川技术近期投资者关系活动记录表显示，公司的工业机器人包括SCARA机器人和六关节机器人。通过近几年的努力，公司SCARA机器人的份额已经超过雅马哈，在中国市场提升到第二名。六关节机器人的竞争对手较多，包括全球四大家族和国产品牌。公司在不断补齐六关节产品系列，尤其是200KG以上重型六关节产品。经过五年的时间，公司工业机器人业务实现盈利，并且盈利情况较好。
# {"id":"chatcmpl-80a1JjSlLhbM2fLfPcfHKtkFYMM56","object":"chat.completion","created":1695149153,"model":"gpt-3.5-turbo-16k-0613","choices":[{"index":0,"message":{"role":"assistant","content":"eval: 利好\nCOT: 根据新闻内容，汇川技术的SCARA机器人在中国市场的份额已经超过雅马哈，提升到第二名，这表明公司在工业机器人领域取得了较好的成绩。此外，公司还在不断补齐六关节产品系列，特别是200KG以上重型六关节产品，这有助于扩大公司在机器人市场的竞争力。另外，新闻还提到公司的工业机器人业务已经实现盈利，并且盈利情况较好。综合以上信息，可以判断这条新闻对汇川技术股票是利好的影响。"},"finish_reason":"stop"}],"usage":{"prompt_tokens":565,"completion_tokens":208,"total_tokens":773,"pre_token_count":16384,"pre_total":339,"adjust_total":326,"final_total":13}}
# stock三联锻造
# content: 【三联锻造：公司为比亚迪仰望U8提供控制臂】财联社9月19日电，三联锻造在互动平台表示，公司为比亚迪仰望U8提供控制臂。
# {"id":"chatcmpl-80a1Tc22hAUqRYAdmBqHTWYUbJhg5","object":"chat.completion","created":1695149163,"model":"gpt-3.5-turbo-16k-0613","choices":[{"index":0,"message":{"role":"assistant","content":"eval: 利好\nCOT: 根据新闻内容，三联锻造公司表示为比亚迪仰望U8提供控制臂。这意味着三联锻造与比亚迪有合作关系，并为其提供零部件。考虑到比亚迪是一家知名的新能源汽车制造商，这一合作对三联锻造来说是一个积极的消息。因此，可以判断这条新闻对三联锻造股票是利好的。"},"finish_reason":"stop"}],"usage":{"prompt_tokens":416,"completion_tokens":146,"total_tokens":562,"pre_token_count":16384,"pre_total":337,"adjust_total":327,"final_total":10}}
# stock东箭科技
# content: 【东箭科技：与问界M7车型有产品合作项目】财联社9月19日电，东箭科技在互动平台表示，目前公司与问界M7车型有产品合作项目，主要为官方纯正精品附件项目，去年第四季度开始供货。目前该项目对公司整体营收的影响较小。
# {"id":"chatcmpl-80a1bBodt0MtID0wV3Ecm3Efzhi60","object":"chat.completion","created":1695149171,"model":"gpt-3.5-turbo-16k-0613","choices":[{"index":0,"message":{"role":"assistant","content":"eval: 中性\nCOT: 这条新闻是关于东箭科技与问界M7车型有产品合作项目的消息。根据新闻内容，这个合作项目主要是为问界M7车型提供官方纯正精品附件，并且从去年第四季度开始供货。然而，新闻中也提到该项目对公司整体营收的影响较小。基于这些信息，我们可以判断这条新闻对东箭科技的影响是中性的，即对股票没有明显的利好或利空影响。"},"finish_reason":"stop"}],"usage":{"prompt_tokens":449,"completion_tokens":164,"total_tokens":613,"pre_token_count":16384,"pre_total":337,"adjust_total":326,"final_total":11}}
# stock聚赛龙
# content: 【聚赛龙：向问界M9、M5车型提供改性PP有关材料】财联社9月19日电，聚赛龙在互动平台表示，截至目前，公司向问界M9、M5车型提供改性PP有关材料，主要应用于挡水条饰条和立柱。
# {"id":"chatcmpl-80a1kz7xoko3fGoPKXbknD46RFNEC","object":"chat.completion","created":1695149180,"model":"gpt-3.5-turbo-16k-0613","choices":[{"index":0,"message":{"role":"assistant","content":"eval: 利好\nCOT: 根据新闻内容，聚赛龙公司向问界M9、M5车型提供改性PP有关材料，主要应用于挡水条饰条和立柱。这意味着聚赛龙公司与问界M9、M5车型有合作关系，并提供了相关材料。由于该新闻没有提到任何负面信息，可以推断这种合作对聚赛龙公司是有利的，有可能带来更多的订单和收入。因此，可以判断这条新闻对聚赛龙股票是利好的。"},"finish_reason":"stop"}],"usage":{"prompt_tokens":444,"completion_tokens":175,"total_tokens":619,"pre_token_count":16384,"pre_total":337,"adjust_total":326,"final_total":11}}
# stock光迅科技
# content: 【光迅科技：1.6T光模块目前处于送样和客户验证阶段】财联社9月19日电，光迅科技在互动平台表示，1.6T光模块目前处于送样和客户验证阶段。
# {"id":"chatcmpl-80a1rpBRPkvSn06u6mhIpJ8726SGy","object":"chat.completion","created":1695149187,"model":"gpt-3.5-turbo-16k-0613","choices":[{"index":0,"message":{"role":"assistant","content":"eval: 利好\nCOT: 根据新闻内容，光迅科技表示其1.6T光模块目前处于送样和客户验证阶段。这意味着公司正在进行新产品的研发和测试，并且已经进入了与客户进行验证的阶段。这表明公司有望推出新的高性能光模块产品，这可能对公司的业绩和市场竞争力产生积极影响，因此可以判断为利好消息。"},"finish_reason":"stop"}],"usage":{"prompt_tokens":423,"completion_tokens":141,"total_tokens":564,"pre_token_count":16384,"pre_total":337,"adjust_total":327,"final_total":10}}
# stock英搏尔
# content: 【英搏尔：集成芯驱动总成产品将在上汽通用五菱等实现量产配套】财联社9月19日电，英搏尔在互动平台表示，公司“集成芯”多合一动力系统实现在吉利睿蓝汽车和上汽大通等车企的配套供应；2023年下半年，公司“集成芯”驱动总成产品还将在上汽通用五菱、江淮汽车、东风汽车、合众汽车等实现量产配套。电源系统产品除配套上述客户外，还有配套包括长城汽车、长安汽车、奇瑞汽车、Vinfast等众多车企。
# {"id":"chatcmpl-80a1yG24TBH1raAHjduiWGoibPEQZ","object":"chat.completion","created":1695149194,"model":"gpt-3.5-turbo-16k-0613","choices":[{"index":0,"message":{"role":"assistant","content":"eval: 利好\nCOT: 根据新闻内容，英搏尔表示其\"集成芯\"多合一动力系统将在吉利睿蓝汽车和上汽大通等车企的配套供应，并且在2023年下半年还将在上汽通用五菱、江淮汽车、东风汽车、合众汽车等实现量产配套。此外，电源系统产品还将配套包括长城汽车、长安汽车、奇瑞汽车、Vinfast等众多车企。这意味着英搏尔的产品将在多家知名车企中得到应用和推广，有望带来更多的订单和收入增长。因此，这条新闻对英搏尔股票的影响是利好的。"},"finish_reason":"stop"}],"usage":{"prompt_tokens":550,"completion_tokens":224,"total_tokens":774,"pre_token_count":16384,"pre_total":339,"adjust_total":326,"final_total":13}}
# stock联赢激光
# content: 【联赢激光：公司半导体产品主要用于先进封装】财联社9月19日电，联赢激光在互动平台表示，公司半导体产品主要用于先进封装。IGBT设备目前已组装完成，正在调试中，尚未形成销售，有意向客户在进行技术对接。
# {"id":"chatcmpl-80a26TvrRmrZBRmc3mgqb6W53yqCW","object":"chat.completion","created":1695149202,"model":"gpt-3.5-turbo-16k-0613","choices":[{"index":0,"message":{"role":"assistant","content":"eval: 利好\nCOT: 根据新闻内容，联赢激光表示其半导体产品主要用于先进封装，并且已经完成了IGBT设备的组装，正在进行调试。虽然尚未形成销售，但有意向客户在进行技术对接。这表明公司在半导体产品领域有进展，并且有潜在的销售机会。因此，这条新闻对联赢激光股票的影响是利好的。"},"finish_reason":"stop"}],"usage":{"prompt_tokens":453,"completion_tokens":148,"total_tokens":601,"pre_token_count":16384,"pre_total":337,"adjust_total":327,"final_total":10}}
# stock北部湾港
# content: 【北部湾港：公司于2023年5月加入华为星闪联盟】财联社9月19日电，北部湾港在互动平台表示，为更好地开展新一代短距离无线网络的研究及应用，推进智慧港口建设，提升北部湾港科技创新水平，公司于2023年5月加入华为星闪联盟，并与华为星闪联盟签订相应的保密协议及承诺书，共同参与推进高性能短距离无线网络的研究及应用。
# {"id":"chatcmpl-80a2C2F5ANqIpIZvOP6x36iLmyKL3","object":"chat.completion","created":1695149208,"model":"gpt-3.5-turbo-16k-0613","choices":[{"index":0,"message":{"role":"assistant","content":"eval: 利好\nCOT: 根据新闻内容，北部湾港在2023年5月加入了华为星闪联盟，并与华为签订了保密协议及承诺书，共同参与推进高性能短距离无线网络的研究及应用。这表明北部湾港将与华为合作，共同推进智慧港口建设，提升科技创新水平。加入华为星闪联盟有助于北部湾港在无线网络领域取得技术突破，提高港口的运营效率和服务质量。因此，这条新闻对北部湾港股票的影响是利好的。"},"finish_reason":"stop"}],"usage":{"prompt_tokens":527,"completion_tokens":213,"total_tokens":740,"pre_token_count":16384,"pre_total":339,"adjust_total":326,"final_total":13}}
# stock厦门信达
# content: 【厦门信达：拟发行长期限含权中期票据和可续期公司债券】财联社9月19日电，厦门信达公告，公司拟向中国银行间市场交易商协会申请注册发行总额不超过10亿元的长期限含权中期票据。同日公告，公司拟发行可续期公司债券不超过10亿元，募集资金扣除发行费用后拟用于补充营运资金及偿还存量有息负债。
# {"id":"chatcmpl-80a2KaHTMVfAPeXJkH7oJRCX2xBih","object":"chat.completion","created":1695149216,"model":"gpt-3.5-turbo-16k-0613","choices":[{"index":0,"message":{"role":"assistant","content":"eval: 利好\nCOT: 这条新闻是关于厦门信达拟发行长期限含权中期票据和可续期公司债券的公告。根据公告内容，公司计划向中国银行间市场交易商协会申请注册发行总额不超过10亿元的长期限含权中期票据，并且还计划发行可续期公司债券不超过10亿元。募集到的资金将用于补充营运资金及偿还存量有息负债。这意味着公司将获得额外的资金支持，有助于提升公司的资金实力和偿债能力，对公司的经营和发展具有积极的影响。因此，这条新闻对厦门信达股票来说是利好消息。"},"finish_reason":"stop"}],"usage":{"prompt_tokens":498,"completion_tokens":238,"total_tokens":736,"pre_token_count":16384,"pre_total":338,"adjust_total":325,"final_total":13}}
# stock经纬纺机
# content: 【经纬纺机：深交所受理公司股票终止上市申请】财联社9月19日电，经纬纺机公告，收到深交所出具的《关于同意受理经纬纺织机械股份有限公司股票终止上市申请的函》。根据该函，深交所正式受理公司股票终止上市申请。根据相关业务规则，深交所在受理公司申请后的十五个交易日内，深交所上市审核委员会将形成审议意见。深交所将根据上市审核委员会的审议意见作出是否终止公司股票上市的决定。小财注：经纬纺机8月29日公告，拟以股东大会决议方式主动终止公司股票上市，并于9月15日召开的2023年第二次临时股东大会审议通过。随后，公司向深交所提交主动终止上市申请材料。
# {"id":"chatcmpl-80a2TtNGGZjwu6zGF0pionNatmqUz","object":"chat.completion","created":1695149225,"model":"gpt-3.5-turbo-16k-0613","choices":[{"index":0,"message":{"role":"assistant","content":"eval: 利空\nCOT: 根据新闻内容，经纬纺机公司已经向深交所提交了股票终止上市的申请，并且深交所已经受理了该申请。根据相关业务规则，深交所将在十五个交易日内形成审议意见，并决定是否终止公司股票的上市。这意味着经纬纺机公司面临着可能被终止上市的风险。因此，这条新闻对经纬纺机股票的影响是利空的。"},"finish_reason":"stop"}],"usage":{"prompt_tokens":652,"completion_tokens":166,"total_tokens":818,"pre_token_count":16384,"pre_total":341,"adjust_total":327,"final_total":14}}
# stock中恒电气
# content: 【中恒电气：子公司拟转让杭州煦达8%股权】财联社9月19日电，中恒电气公告，公司全资子公司中恒云能源拟将其持有的参股公司杭州煦达8%的股权转让给杭州文狄隽升投资合伙企业（有限合伙），转让价款为2400万元。本次股权转让完成后，中恒云能源持有杭州煦达16%的股权。
# {"id":"chatcmpl-80a2aibNbsIorBQqduMftoXuMnnUa","object":"chat.completion","created":1695149232,"model":"gpt-3.5-turbo-16k-0613","choices":[{"index":0,"message":{"role":"assistant","content":"eval: 利好\nCOT: 根据新闻内容，中恒电气的子公司中恒云能源计划将其持有的杭州煦达8%的股权转让给杭州文狄隽升投资合伙企业。这意味着中恒电气将获得2400万元的转让价款，并且中恒云能源仍然持有杭州煦达16%的股权。这笔交易可能会为中恒电气带来一定的资金收入，对公司的财务状况有所改善，因此可以判断为利好消息。"},"finish_reason":"stop"}],"usage":{"prompt_tokens":501,"completion_tokens":182,"total_tokens":683,"pre_token_count":16384,"pre_total":338,"adjust_total":326,"final_total":12}}
# stock东北制药
# content: 【东北制药：拟在阿曼苏丹国投资组建一家医药企业】财联社9月19日电，东北制药公告，公司与Muscat Changming Investments LLC（马斯喀特昌明）拟在阿曼苏丹国投资组建一家医药企业。经友好协商，双方于近日签署《马斯喀特昌明投资有限公司和东北制药集团股份有限公司投资框架协议》，以增进合作双方的共识理解、推动合作进程。
# {"id":"chatcmpl-80a2jhG0QZIXSwsVFnGSvJUVG3fsn","object":"chat.completion","created":1695149241,"model":"gpt-3.5-turbo-16k-0613","choices":[{"index":0,"message":{"role":"assistant","content":"eval: 利好\nCOT: 根据新闻内容，东北制药计划与马斯喀特昌明在阿曼苏丹国投资组建一家医药企业。这表明东北制药有意扩大海外市场，并与当地企业合作。这一举措有助于东北制药拓展国际业务，增加收入来源。因此，这条新闻对东北制药股票来说是利好消息。"},"finish_reason":"stop"}],"usage":{"prompt_tokens":518,"completion_tokens":139,"total_tokens":657,"pre_token_count":16384,"pre_total":339,"adjust_total":328,"final_total":11}}
# stock通宇通讯
# content: 【通宇通讯：公司在5.5G、6G的天线领域已有相关技术积累】财联社9月19日电，通宇通讯在互动平台表示，公司一直高度重视新技术的研究与开发运用，在5.5G、6G的天线领域已有相关技术积累；5.5G仍未进入商用阶段，将密切关注技术发展。公司与华为主要合作在微波天线、基站天线、授时定位天线领域。
# {"id":"chatcmpl-80a2r13sU9k4mXt51jlCygYUITt8H","object":"chat.completion","created":1695149249,"model":"gpt-3.5-turbo-16k-0613","choices":[{"index":0,"message":{"role":"assistant","content":"eval: 利好\nCOT: 根据新闻内容，通宇通讯在5.5G、6G的天线领域已有相关技术积累，并且与华为在微波天线、基站天线、授时定位天线领域有合作。这表明通宇通讯在未来的5.5G和6G技术发展中具备一定的竞争优势，有望获得更多的合作机会和市场份额。因此，这条新闻对通宇通讯股票的影响是利好的。"},"finish_reason":"stop"}],"usage":{"prompt_tokens":511,"completion_tokens":166,"total_tokens":677,"pre_token_count":16384,"pre_total":338,"adjust_total":327,"final_total":11}}
# stock怡达股份
# content: 【怡达股份：尽可能多生产多销售利润相对高、经济效益好的双氧水产品】财联社9月19日电，怡达股份在互动平台表示，公司将根据市场变化和客户需求情况调整双氧水产品和环氧丙烷产品的生产比例，目前尽可能多生产多销售利润相对高、经济效益好的双氧水产品，以达到既保证产品结构相对平衡合理，又实现企业经济利益最好的结果。
# {"id":"chatcmpl-80a2yq0ICjFhHN47AKl8y73tsHPtC","object":"chat.completion","created":1695149256,"model":"gpt-3.5-turbo-16k-0613","choices":[{"index":0,"message":{"role":"assistant","content":"eval: 利好\nCOT: 根据新闻内容，怡达股份表示将根据市场变化和客户需求情况调整双氧水产品和环氧丙烷产品的生产比例，目前将尽可能多生产多销售利润相对高、经济效益好的双氧水产品。这表明公司对双氧水产品的市场需求较高，并且希望通过增加双氧水产品的生产和销售来提高企业的经济利益。因此，这条新闻对怡达股份是利好消息，有助于提升股票的价值。"},"finish_reason":"stop"}],"usage":{"prompt_tokens":519,"completion_tokens":188,"total_tokens":707,"pre_token_count":16384,"pre_total":339,"adjust_total":327,"final_total":12}}
# stock韵达股份
# content: 【韵达股份：8月快递服务业务收入同比下降9.94%】财联社9月19日电，韵达股份公告，8月快递服务业务收入35.16亿元，同比下降9.94%。
# {"id":"chatcmpl-80a35asmUfgrxYtvOIrmAs2jJo133","object":"chat.completion","created":1695149263,"model":"gpt-3.5-turbo-16k-0613","choices":[{"index":0,"message":{"role":"assistant","content":"eval: 利空\nCOT: 根据新闻内容，韵达股份公告显示，其8月份的快递服务业务收入同比下降9.94%。这意味着韵达股份在该月份的业务收入出现了下滑。由于快递服务业务是韵达股份的主要收入来源，收入下降可能意味着公司的业绩受到了影响。因此，这条新闻对韵达股份来说是利空的。"},"finish_reason":"stop"}],"usage":{"prompt_tokens":422,"completion_tokens":152,"total_tokens":574,"pre_token_count":16384,"pre_total":337,"adjust_total":327,"final_total":10}}
# stock申通快递
# content: 【申通快递：8月快递服务业务收入同比增长7.63%】财联社9月19日电，申通快递公告，8月快递服务业务收入31.88亿元，同比增长7.63%。
# {"id":"chatcmpl-80a3CbzpgED7p6ZZT0yhY2lkg1sbY","object":"chat.completion","created":1695149270,"model":"gpt-3.5-turbo-16k-0613","choices":[{"index":0,"message":{"role":"assistant","content":"eval: 利好\nCOT: 根据新闻内容，申通快递在8月份的快递服务业务收入同比增长了7.63%。这意味着申通快递的业务增长势头良好，公司的收入有所增加。这对申通快递股票来说是一个利好消息，可能会提升投资者对该股票的信心，有助于股价上涨。因此，我判断这条新闻对申通快递股票是利好的影响。"},"finish_reason":"stop"}],"usage":{"prompt_tokens":420,"completion_tokens":160,"total_tokens":580,"pre_token_count":16384,"pre_total":337,"adjust_total":327,"final_total":10}}
# stock东方财富
# content: 【东方财富：签署最高额保证合同】财联社9月19日电，东方财富公告，公司全资子公司天天基金因业务发展需要，与光大银行上海分行继续开展合作，合作协议期限为一年。公司为天天基金提供最高额连带责任保证担保，以担保天天基金足额清偿其在相关合作协议项下产生的全部债务，担保的主债权最高余额合计为10.00亿元。承担保证责任期间为具体授信业务合同或协议约定的天天基金履行债务期限届满之日起三年。上述担保相关最高额保证合同已完成签署。
# {"id":"chatcmpl-80a3IbESYty6a3Mu1PWN6LM9ejfuD","object":"chat.completion","created":1695149276,"model":"gpt-3.5-turbo-16k-0613","choices":[{"index":0,"message":{"role":"assistant","content":"eval: 利好\nCOT: 根据新闻内容，东方财富与光大银行上海分行签署了一份最高额保证合同，担保了其全资子公司天天基金在合作协议项下产生的全部债务。这意味着东方财富为天天基金提供了担保，确保其能够清偿债务。这对于东方财富来说是一个积极的消息，表明公司对其子公司的业务发展有信心，并且有能力提供必要的支持和保障。因此，这条新闻对东方财富股票来说是利好的。"},"finish_reason":"stop"}],"usage":{"prompt_tokens":572,"completion_tokens":192,"total_tokens":764,"pre_token_count":16384,"pre_total":340,"adjust_total":327,"final_total":13}}
# stock双环科技
# content: 【双环科技：拟与国电投荆楚能源有限公司签订合作意向协议】财联社9月19日电，双环科技公告，拟与国电投荆楚能源有限公司签订《合作意向协议》，公司拟通过出租、转让盐穴资源等多种方式，与国电投荆楚能源有限公司拟建设应城300MW级压缩空气储能电站工程项目开展合作。
# {"id":"chatcmpl-80a3Qz4hv0T9FGFvmhm3CRMvzbBQj","object":"chat.completion","created":1695149284,"model":"gpt-3.5-turbo-16k-0613","choices":[{"index":0,"message":{"role":"assistant","content":"eval: 利好\nCOT: 根据新闻内容，双环科技计划与国电投荆楚能源有限公司签订合作意向协议，拟建设应城300MW级压缩空气储能电站工程项目。这意味着双环科技有机会参与到储能电站项目的建设中，这对于公司来说是一个利好消息。储能电站是未来能源领域的重要发展方向，参与其中有助于公司的技术积累和市场拓展。因此，可以判断这条新闻对双环科技股票是利好的影响。"},"finish_reason":"stop"}],"usage":{"prompt_tokens":485,"completion_tokens":187,"total_tokens":672,"pre_token_count":16384,"pre_total":338,"adjust_total":326,"final_total":12}}
# stock圆通速递
# content: 【圆通速递：8月快递产品收入同比增长6.19%】财联社9月19日电，圆通速递公告，8月快递产品收入40.67亿元，同比增长6.19%。
# {"id":"chatcmpl-80a3Z30ArVbDRFXj0IGFQqs6D0W5D","object":"chat.completion","created":1695149293,"model":"gpt-3.5-turbo-16k-0613","choices":[{"index":0,"message":{"role":"assistant","content":"eval: 利好\nCOT: 根据新闻内容，圆通速递在8月份的快递产品收入同比增长了6.19%，这表明公司的业务增长态势良好。快递行业是一个与经济发展密切相关的行业，增长的快递产品收入意味着更多的订单和业务量，对公司的盈利能力有积极影响。因此，这条新闻对圆通速递股票来说是利好消息。"},"finish_reason":"stop"}],"usage":{"prompt_tokens":413,"completion_tokens":148,"total_tokens":561,"pre_token_count":16384,"pre_total":336,"adjust_total":326,"final_total":10}}
# stock分众传媒
# content: 【分众传媒：媒体刊例价已恢复常规性价格上调】财联社9月19日电，在今日举行的2023年半年度业绩会上，分众传媒董事长江南春表示，自2023年7月起，公司的电梯电视媒体网络、电梯海报及电梯智能屏三种媒体的刊例价已恢复常规性价格上调。在宏观环境无重大变化的前提下，公司预计明年1月仍将继续维持常规性价格上调政策。（财联社记者 崔铭）
# {"id":"chatcmpl-80a3fi1vmVYZEUdEqYKvZ1VetxgvR","object":"chat.completion","created":1695149299,"model":"gpt-3.5-turbo-16k-0613","choices":[{"index":0,"message":{"role":"assistant","content":"eval: 利好\nCOT: 这条新闻是关于分众传媒在2023年半年度业绩会上宣布，自2023年7月起，公司的电梯电视媒体网络、电梯海报及电梯智能屏三种媒体的刊例价已恢复常规性价格上调。这意味着分众传媒将提高广告媒体的价格，可能会增加公司的收入。考虑到公司预计明年1月仍将继续维持常规性价格上调政策，可以认为这是一个利好消息，对分众传媒的股票有积极的影响。"},"finish_reason":"stop"}],"usage":{"prompt_tokens":538,"completion_tokens":199,"total_tokens":737,"pre_token_count":16384,"pre_total":339,"adjust_total":326,"final_total":13}}
# stock铭科精技
# content: 【铭科精技：近期公司下游客户赛力斯的AITO问界新M7上市并开启交付】财联社9月19日电，铭科精技披露股票交易异常波动公告，近期公司下游客户赛力斯的AITO问界新M7上市并开启交付，引起市场广泛关注。公司目前经营情况及内外部经营环境未发生重大变化。在此公司提醒广大投资者注意投资风险，理性投资。
# {"id":"chatcmpl-80a3mIVqdA5nDH1hincoQc2B5QfX2","object":"chat.completion","created":1695149306,"model":"gpt-3.5-turbo-16k-0613","choices":[{"index":0,"message":{"role":"assistant","content":"eval: 中性\nCOT: 这条新闻是关于铭科精技的下游客户赛力斯的AITO问界新M7上市并开启交付的消息。根据新闻内容，公司的经营情况及内外部经营环境未发生重大变化。虽然这个消息引起了市场的广泛关注，但是没有提到具体的影响和利好信息。因此，无法确定这条新闻对铭科精技股票的利好程度，评估为中性。"},"finish_reason":"stop"}],"usage":{"prompt_tokens":503,"completion_tokens":153,"total_tokens":656,"pre_token_count":16384,"pre_total":338,"adjust_total":327,"final_total":11}}
# stock爱司凯
# content: 【爱司凯：256路CTP设备可支持高分辨率光刻胶曝光】财联社9月19日电，爱司凯在互动平台表示，公司生产的256路CTP设备（分辨率12800DPI）可支持高分辨率光刻胶曝光，但目前公司产品不应用于半导体加工领域。
# {"id":"chatcmpl-80a3vC0c5vLj1HkmmRzIasxPUPfOv","object":"chat.completion","created":1695149315,"model":"gpt-3.5-turbo-16k-0613","choices":[{"index":0,"message":{"role":"assistant","content":"eval: 利好\nCOT: 根据新闻内容，爱司凯表示他们生产的256路CTP设备可以支持高分辨率光刻胶曝光。这意味着他们的设备在印刷行业有更广泛的应用。虽然目前公司产品不应用于半导体加工领域，但这一技术的进步可能会为公司带来更多的商机和市场需求。因此，这条新闻对爱司凯股票的影响是利好的。"},"finish_reason":"stop"}],"usage":{"prompt_tokens":458,"completion_tokens":155,"total_tokens":613,"pre_token_count":16384,"pre_total":337,"adjust_total":327,"final_total":10}}
# stock海大集团
# content: 【海大集团：终止公司2022年度向特定对象发行A股股票事项】财联社9月19日电，海大集团公告，终止公司2022年度向特定对象发行A股股票事项并撤回申请文件。
# {"id":"chatcmpl-80a42m5f78gkxgEjm00HL3fKk1sB8","object":"chat.completion","created":1695149322,"model":"gpt-3.5-turbo-16k-0613","choices":[{"index":0,"message":{"role":"assistant","content":"eval: 利空\nCOT: 根据新闻内容，海大集团终止了向特定对象发行A股股票的计划并撤回了申请文件。这意味着公司无法通过发行股票来融资，可能会影响到公司的资金筹措能力和发展计划。因此，这条新闻对海大集团股票的影响是利空的。"},"finish_reason":"stop"}],"usage":{"prompt_tokens":423,"completion_tokens":122,"total_tokens":545,"pre_token_count":16384,"pre_total":337,"adjust_total":328,"final_total":9}}
# stock顺丰控股
# content: 【顺丰控股：8月速运物流业务营收150.54亿元 同比增长2.41%】财联社9月19日电，顺丰控股公告，8月速运物流业务营收150.54亿元，同比增长2.41%；供应链及国际业务营收52.18亿元，同比下降27.41%。
# {"id":"chatcmpl-80a49loLT1Y0f02lefIDhl2VVmx6o","object":"chat.completion","created":1695149329,"model":"gpt-3.5-turbo-16k-0613","choices":[{"index":0,"message":{"role":"assistant","content":"eval: 利好\nCOT: 根据新闻内容，顺丰控股在8月份的速运物流业务营收同比增长2.41%，这是一个正向的增长趋势，说明公司的业务在增长。虽然供应链及国际业务营收同比下降27.41%，但是这个下降幅度相对较小，不足以抵消速运物流业务的增长。因此，可以判断这条新闻对顺丰控股是利好的。"},"finish_reason":"stop"}],"usage":{"prompt_tokens":455,"completion_tokens":151,"total_tokens":606,"pre_token_count":16384,"pre_total":337,"adjust_total":327,"final_total":10}}
# stock秦川机床
# content: 【秦川机床：子公司拟投建高档数控机床工业园项目】财联社9月19日电，秦川机床公告，控股子公司投资建设“宝鸡机床集团高档数控机床工业园（一期）项目”，项目总投资3.6亿元。
# {"id":"chatcmpl-80a4FwMu30uNtRnhkSEVrnUv4LVdH","object":"chat.completion","created":1695149335,"model":"gpt-3.5-turbo-16k-0613","choices":[{"index":0,"message":{"role":"assistant","content":"eval: 利好\nCOT: 根据新闻内容，秦川机床的子公司计划投资建设高档数控机床工业园项目，项目总投资达3.6亿元。这表明秦川机床有意扩大生产规模和提升产品质量，进一步巩固其在数控机床领域的竞争优势。投资建设高档数控机床工业园项目将有助于提高秦川机床的生产能力和技术水平，进一步拓展市场份额，从而对秦川机床的发展具有积极的影响。因此，这条新闻对秦川机床股票来说是利好消息。"},"finish_reason":"stop"}],"usage":{"prompt_tokens":446,"completion_tokens":220,"total_tokens":666,"pre_token_count":16384,"pre_total":337,"adjust_total":325,"final_total":12}}
# stock爱司凯
# content: 【爱司凯：3D砂型打印机实现了量产销售】财联社9月19日电，爱司凯在互动平台表示，公司已掌握砂型3D打印的核心技术，实现了3D砂型打印机量产销售。公司开发生产的3D砂型系列打印设备在国内相关企业已进入生产级使用，为相关行业提供砂芯、砂型及金属铸件成品的生产供应。截至目前，公司自主研发的T2500、S2000、S1800、T1800、S801均已实现批量生产和销售。公司是3D喷墨领域拥有喷墨打印头自主知识产权的品牌，整个打印系统实现了自主研发生产。公司正在打印测试的8激光3D打印头技术适合打印精密金属零部件。
# {"id":"chatcmpl-80a4PmHjWbn3Mbh6N3PlhwhhOIxqR","object":"chat.completion","created":1695149345,"model":"gpt-3.5-turbo-16k-0613","choices":[{"index":0,"message":{"role":"assistant","content":"eval: 利好\nCOT: 根据新闻内容，爱司凯已经掌握了砂型3D打印的核心技术，并实现了量产销售。公司的3D砂型系列打印设备已经进入生产级使用，并为相关行业提供砂芯、砂型及金属铸件成品的生产供应。此外，公司还拥有喷墨打印头自主知识产权，并实现了自主研发生产的整个打印系统。根据这些信息，可以判断该新闻对爱司凯股票是利好的，因为公司在3D打印领域取得了重要的进展，有望带来更多的销售和收入增长。"},"finish_reason":"stop"}],"usage":{"prompt_tokens":637,"completion_tokens":220,"total_tokens":857,"pre_token_count":16384,"pre_total":341,"adjust_total":327,"final_total":14}}
# stock中国天楹
# content: 【中国天楹：签署100MWh重力储能项目合作协议】财联社9月19日电，中国天楹公告，子公司江苏能楹与右玉县人民政府签署100MWh重力储能项目合作协议。
# {"id":"chatcmpl-80a4XOPzxTSB1Ie7BXgUYQbhQ7IfA","object":"chat.completion","created":1695149353,"model":"gpt-3.5-turbo-16k-0613","choices":[{"index":0,"message":{"role":"assistant","content":"eval: 利好\nCOT: 根据新闻内容，中国天楹的子公司江苏能楹与右玉县人民政府签署了100MWh重力储能项目合作协议。重力储能是一种新兴的能源储存技术，具有较高的储能效率和环保性。这个合作协议意味着中国天楹将参与到重力储能项目中，有望获得相关的技术和市场机会。因此，这条新闻对中国天楹股票的影响是利好的。"},"finish_reason":"stop"}],"usage":{"prompt_tokens":420,"completion_tokens":166,"total_tokens":586,"pre_token_count":16384,"pre_total":337,"adjust_total":327,"final_total":10}}
# stock晶方科技
# content: 【晶方科技：计划调整投资项目股权】财联社9月19日电，晶方科技公告，公司计划对投资的荷兰Anteryon公司、以色列VisIC公司的股权架构进行调整。将晶方光电持有的荷兰Anteryon公司77.8%的股权变更到新加坡OPTIZ TECH公司；协同晶方贰号产业基金在新加坡成立OPTIZ HOLD公司，并将公司、晶方贰号产业基金分别持有的以色列VisIC公司18.06%、33.31%股权变更到OPTIZ HOLD公司。
# {"id":"chatcmpl-80a4fo1qVBsHwkW6S14nPOM1ZEIGn","object":"chat.completion","created":1695149361,"model":"gpt-3.5-turbo-16k-0613","choices":[{"index":0,"message":{"role":"assistant","content":"eval: 利好\nCOT: 根据新闻内容，晶方科技计划调整对荷兰Anteryon公司和以色列VisIC公司的股权架构。将晶方光电持有的荷兰Anteryon公司的股权变更到新加坡OPTIZ TECH公司，同时将晶方贰号产业基金持有的以色列VisIC公司的股权变更到OPTIZ HOLD公司。这意味着晶方科技将通过调整股权结构来优化投资项目，可能会带来更好的投资回报。因此，这条新闻对晶方科技股票的影响是利好的。"},"finish_reason":"stop"}],"usage":{"prompt_tokens":522,"completion_tokens":184,"total_tokens":706,"pre_token_count":16384,"pre_total":339,"adjust_total":327,"final_total":12}}
# stock沃森生物
# content: 【沃森生物：13价肺炎结合疫苗获印度尼西亚2p+1免疫程序Ⅲ期临床试验批件】财联社9月19日电，沃森生物公告，子公司玉溪沃森的13价肺炎结合疫苗获印度尼西亚2p+1免疫程序Ⅲ期临床试验批件。
# {"id":"chatcmpl-80a4q1hvoN3xapnOpOnbmyUD76sVZ","object":"chat.completion","created":1695149372,"model":"gpt-3.5-turbo-16k-0613","choices":[{"index":0,"message":{"role":"assistant","content":"eval: 利好\nCOT: 根据新闻内容，沃森生物的子公司玉溪沃森的13价肺炎结合疫苗获得了印度尼西亚2p+1免疫程序Ⅲ期临床试验批件。这意味着沃森生物在开展该疫苗的临床试验方面取得了进展，有望在未来获得更多的认可和市场机会。因此，这条新闻对沃森生物股票来说是利好消息。"},"finish_reason":"stop"}],"usage":{"prompt_tokens":477,"completion_tokens":165,"total_tokens":642,"pre_token_count":16384,"pre_total":338,"adjust_total":327,"final_total":11}}
# stock赛福天
# content: 【赛福天：签订单晶N型TOPCon电池片销售合同】财联社9月19日电，赛福天公告，公司签署日常销售框架合同，合同约定2023年11月1日起至2024年12月31日，公司及赛福天新能源向一道新能源、一道光伏、一道新能供应单晶N型TOPCon电池片数量合计1.68亿片。
# {"id":"chatcmpl-80a4xIwAZQZ4jEfkmm5QsubqRlh3l","object":"chat.completion","created":1695149379,"model":"gpt-3.5-turbo-16k-0613","choices":[{"index":0,"message":{"role":"assistant","content":"eval: 利好\nCOT: 根据新闻内容，赛福天签署了一份销售合同，合同约定了公司及赛福天新能源向一道新能源、一道光伏、一道新能供应单晶N型TOPCon电池片的数量合计1.68亿片。这意味着赛福天将有大量的订单销售，对公司的业绩和收入将产生积极的影响。因此，这条新闻对赛福天股票来说是利好的消息。"},"finish_reason":"stop"}],"usage":{"prompt_tokens":474,"completion_tokens":157,"total_tokens":631,"pre_token_count":16384,"pre_total":338,"adjust_total":327,"final_total":11}}
# stock海联金汇
# content: 【海联金汇：拟以3亿元-6亿元回购股份】财联社9月19日电，海联金汇公告，拟以3亿元-6亿元回购股份，用于后续实施员工持股计划或者股权激励计划。回购价格不超过人民币9元/股。
# {"id":"chatcmpl-80a5366m9pXFC6ehDjllyVfyjptRt","object":"chat.completion","created":1695149385,"model":"gpt-3.5-turbo-16k-0613","choices":[{"index":0,"message":{"role":"assistant","content":"eval: 利好\nCOT: 这条新闻是关于海联金汇拟以3亿元-6亿元回购股份的公告。回购股份通常被视为一种利好消息，因为它表明公司认为股票的价值被低估，并且有意增加股东的权益。此外，回购股份还可以提高每股收益和股东价值。因此，根据这条新闻，可以判断对海联金汇股票是利好的。"},"finish_reason":"stop"}],"usage":{"prompt_tokens":443,"completion_tokens":147,"total_tokens":590,"pre_token_count":16384,"pre_total":337,"adjust_total":327,"final_total":10}}
